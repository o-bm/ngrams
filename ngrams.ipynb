# %%
words = open('names.txt', 'r').read().splitlines()

# %%
for w in words[:10]:
    print(w)
# Out:
# emma
# olivia
# ava
# isabella
# sophia
# charlotte
# mia
# amelia
# harper
# evelyn

# %%
print(len(words))
# Out:
# 32033

# %%
min(len(w) for w in words)
# Out:
# 2

# %%
max(len(w) for w in words)
# Out:
# 15

# %%
print

# %% [raw]
# max(len(
